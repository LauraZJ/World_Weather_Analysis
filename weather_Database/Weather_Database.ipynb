# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
Lat_lng = list(coordinates)
len(Lat_lng)
# Out:
# 2000

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a list of the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Create an empty list to hold the weather data.
cities_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]

        
        
        # Convert the date to ISO standard.
        cities_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        cities_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description
                            
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | krasnozatonskiy
# Processing Record 2 of Set 1 | carutapera
# Processing Record 3 of Set 1 | valparaiso
# Processing Record 4 of Set 1 | ciudad bolivar
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | maniitsoq
# Processing Record 7 of Set 1 | tamandare
# Processing Record 8 of Set 1 | victoria
# Processing Record 9 of Set 1 | lagoa
# Processing Record 10 of Set 1 | deputatskiy
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | nikolskoye
# Processing Record 13 of Set 1 | beringovskiy
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | klyuchi
# Processing Record 16 of Set 1 | tasiilaq
# Processing Record 17 of Set 1 | veraval
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | acu
# Processing Record 20 of Set 1 | san cristobal
# Processing Record 21 of Set 1 | clyde river
# Processing Record 22 of Set 1 | manali
# Processing Record 23 of Set 1 | gunnedah
# Processing Record 24 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | qaanaaq
# Processing Record 27 of Set 1 | arraial do cabo
# Processing Record 28 of Set 1 | mbandaka
# Processing Record 29 of Set 1 | pathein
# Processing Record 30 of Set 1 | lompoc
# Processing Record 31 of Set 1 | bambous virieux
# Processing Record 32 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 33 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 1 | saldanha
# Processing Record 35 of Set 1 | saint-philippe
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | sorland
# Processing Record 38 of Set 1 | beyneu
# Processing Record 39 of Set 1 | iqaluit
# Processing Record 40 of Set 1 | talnakh
# Processing Record 41 of Set 1 | khatanga
# Processing Record 42 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 1 | cape town
# Processing Record 44 of Set 1 | atuona
# Processing Record 45 of Set 1 | sisimiut
# Processing Record 46 of Set 1 | paamiut
# Processing Record 47 of Set 1 | vardo
# Processing Record 48 of Set 1 | port-gentil
# Processing Record 49 of Set 1 | cairns
# Processing Record 50 of Set 1 | fortuna
# Processing Record 1 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 2 | port alfred
# Processing Record 3 of Set 2 | nexo
# Processing Record 4 of Set 2 | cherskiy
# Processing Record 5 of Set 2 | bredasdorp
# Processing Record 6 of Set 2 | kempele
# Processing Record 7 of Set 2 | hithadhoo
# Processing Record 8 of Set 2 | dikson
# Processing Record 9 of Set 2 | punta arenas
# Processing Record 10 of Set 2 | tuktoyaktuk
# Processing Record 11 of Set 2 | kapaa
# Processing Record 12 of Set 2 | port hardy
# Processing Record 13 of Set 2 | merauke
# Processing Record 14 of Set 2 | vanavara
# Processing Record 15 of Set 2 | sal rei
# Processing Record 16 of Set 2 | butaritari
# Processing Record 17 of Set 2 | kahului
# Processing Record 18 of Set 2 | upernavik
# Processing Record 19 of Set 2 | kathu
# Processing Record 20 of Set 2 | taltal
# Processing Record 21 of Set 2 | pevek
# Processing Record 22 of Set 2 | fairbanks
# Processing Record 23 of Set 2 | hilo
# Processing Record 24 of Set 2 | tabuk
# Processing Record 25 of Set 2 | husavik
# Processing Record 26 of Set 2 | nome
# Processing Record 27 of Set 2 | padang
# Processing Record 28 of Set 2 | faya
# Processing Record 29 of Set 2 | mirnyy
# Processing Record 30 of Set 2 | berlevag
# Processing Record 31 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 2 | suntar
# Processing Record 33 of Set 2 | dunmore town
# Processing Record 34 of Set 2 | itacare
# Processing Record 35 of Set 2 | east london
# Processing Record 36 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 2 | tuatapere
# Processing Record 38 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 2 | ilulissat
# Processing Record 40 of Set 2 | muros
# Processing Record 41 of Set 2 | vaini
# Processing Record 42 of Set 2 | pemangkat
# Processing Record 43 of Set 2 | utica
# Processing Record 44 of Set 2 | port-de-bouc
# Processing Record 45 of Set 2 | bethel
# Processing Record 46 of Set 2 | nador
# Processing Record 47 of Set 2 | olafsvik
# Processing Record 48 of Set 2 | mount isa
# Processing Record 49 of Set 2 | ilembo
# Processing Record 50 of Set 2 | tefe
# Processing Record 1 of Set 3 | barrow
# Processing Record 2 of Set 3 | ilave
# Processing Record 3 of Set 3 | ilebo
# Processing Record 4 of Set 3 | atbasar
# Processing Record 5 of Set 3 | avarua
# Processing Record 6 of Set 3 | souillac
# Processing Record 7 of Set 3 | whitehorse
# Processing Record 8 of Set 3 | cabo san lucas
# Processing Record 9 of Set 3 | carnarvon
# Processing Record 10 of Set 3 | norman wells
# Processing Record 11 of Set 3 | oga
# Processing Record 12 of Set 3 | northam
# Processing Record 13 of Set 3 | dunedin
# Processing Record 14 of Set 3 | taree
# Processing Record 15 of Set 3 | ponta do sol
# Processing Record 16 of Set 3 | salalah
# Processing Record 17 of Set 3 | golspie
# Processing Record 18 of Set 3 | komsomolskiy
# Processing Record 19 of Set 3 | port elizabeth
# Processing Record 20 of Set 3 | moroni
# Processing Record 21 of Set 3 | new norfolk
# Processing Record 22 of Set 3 | airai
# Processing Record 23 of Set 3 | talawdi
# City not found. Skipping...
# Processing Record 24 of Set 3 | ust-kuyga
# Processing Record 25 of Set 3 | torbat-e jam
# Processing Record 26 of Set 3 | mwinilunga
# Processing Record 27 of Set 3 | aurangabad
# Processing Record 28 of Set 3 | mahebourg
# Processing Record 29 of Set 3 | haines junction
# Processing Record 30 of Set 3 | korla
# Processing Record 31 of Set 3 | gigmoto
# Processing Record 32 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 3 | njombe
# Processing Record 34 of Set 3 | pandan
# Processing Record 35 of Set 3 | aljezur
# Processing Record 36 of Set 3 | chuy
# Processing Record 37 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 3 | salinas
# Processing Record 39 of Set 3 | tres lagoas
# Processing Record 40 of Set 3 | hermanus
# Processing Record 41 of Set 3 | alushta
# Processing Record 42 of Set 3 | provideniya
# Processing Record 43 of Set 3 | svetlogorsk
# Processing Record 44 of Set 3 | faanui
# Processing Record 45 of Set 3 | tiznit
# Processing Record 46 of Set 3 | gizo
# Processing Record 47 of Set 3 | castro
# Processing Record 48 of Set 3 | porbandar
# Processing Record 49 of Set 3 | wieliczka
# Processing Record 50 of Set 3 | la rioja
# Processing Record 1 of Set 4 | ahipara
# Processing Record 2 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 4 | richards bay
# Processing Record 4 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 4 | port lincoln
# Processing Record 6 of Set 4 | ayan
# Processing Record 7 of Set 4 | henties bay
# Processing Record 8 of Set 4 | jujuy
# City not found. Skipping...
# Processing Record 9 of Set 4 | impfondo
# Processing Record 10 of Set 4 | longyearbyen
# Processing Record 11 of Set 4 | beeville
# Processing Record 12 of Set 4 | nemuro
# Processing Record 13 of Set 4 | ixtapa
# Processing Record 14 of Set 4 | kerman
# Processing Record 15 of Set 4 | hasaki
# Processing Record 16 of Set 4 | sao joao da barra
# Processing Record 17 of Set 4 | hualmay
# Processing Record 18 of Set 4 | bintulu
# Processing Record 19 of Set 4 | shizunai
# Processing Record 20 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 21 of Set 4 | boma
# Processing Record 22 of Set 4 | dalby
# Processing Record 23 of Set 4 | puerto ayora
# Processing Record 24 of Set 4 | dinsor
# City not found. Skipping...
# Processing Record 25 of Set 4 | barguzin
# Processing Record 26 of Set 4 | itarema
# Processing Record 27 of Set 4 | jacksonville
# Processing Record 28 of Set 4 | ipixuna
# Processing Record 29 of Set 4 | lyubim
# Processing Record 30 of Set 4 | te anau
# Processing Record 31 of Set 4 | codrington
# Processing Record 32 of Set 4 | lazaro cardenas
# Processing Record 33 of Set 4 | viedma
# Processing Record 34 of Set 4 | floro
# Processing Record 35 of Set 4 | ambilobe
# Processing Record 36 of Set 4 | akdepe
# Processing Record 37 of Set 4 | srednekolymsk
# Processing Record 38 of Set 4 | yibin
# Processing Record 39 of Set 4 | oum hadjer
# Processing Record 40 of Set 4 | little elm
# Processing Record 41 of Set 4 | kargasok
# Processing Record 42 of Set 4 | hobart
# Processing Record 43 of Set 4 | severo-kurilsk
# Processing Record 44 of Set 4 | kodinsk
# Processing Record 45 of Set 4 | taoudenni
# Processing Record 46 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 4 | murwara
# Processing Record 48 of Set 4 | guerrero negro
# Processing Record 49 of Set 4 | bengkulu
# Processing Record 50 of Set 4 | yellowknife
# Processing Record 1 of Set 5 | kavieng
# Processing Record 2 of Set 5 | chokurdakh
# Processing Record 3 of Set 5 | colquechaca
# Processing Record 4 of Set 5 | shizuishan
# Processing Record 5 of Set 5 | kodiak
# Processing Record 6 of Set 5 | riyadh
# Processing Record 7 of Set 5 | klaksvik
# Processing Record 8 of Set 5 | kamaishi
# Processing Record 9 of Set 5 | inuvik
# Processing Record 10 of Set 5 | rexburg
# Processing Record 11 of Set 5 | leningradskiy
# Processing Record 12 of Set 5 | kulhudhuffushi
# Processing Record 13 of Set 5 | buchanan
# Processing Record 14 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 15 of Set 5 | luderitz
# Processing Record 16 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 5 | del gallego
# Processing Record 18 of Set 5 | kaeo
# Processing Record 19 of Set 5 | djambala
# Processing Record 20 of Set 5 | pundaguitan
# Processing Record 21 of Set 5 | berdigestyakh
# Processing Record 22 of Set 5 | bichura
# Processing Record 23 of Set 5 | bluff
# Processing Record 24 of Set 5 | shimoni
# Processing Record 25 of Set 5 | bay roberts
# Processing Record 26 of Set 5 | mount gambier
# Processing Record 27 of Set 5 | san cosme y damian
# Processing Record 28 of Set 5 | aniva
# Processing Record 29 of Set 5 | luwingu
# Processing Record 30 of Set 5 | xining
# Processing Record 31 of Set 5 | los llanos de aridane
# Processing Record 32 of Set 5 | ca mau
# Processing Record 33 of Set 5 | pychas
# Processing Record 34 of Set 5 | aklavik
# Processing Record 35 of Set 5 | vestmannaeyjar
# Processing Record 36 of Set 5 | raahe
# Processing Record 37 of Set 5 | oudtshoorn
# Processing Record 38 of Set 5 | misawa
# Processing Record 39 of Set 5 | biltine
# Processing Record 40 of Set 5 | tingrela
# City not found. Skipping...
# Processing Record 41 of Set 5 | rawson
# Processing Record 42 of Set 5 | rio grande
# Processing Record 43 of Set 5 | mar del plata
# Processing Record 44 of Set 5 | tiksi
# Processing Record 45 of Set 5 | naze
# Processing Record 46 of Set 5 | jacareacanga
# Processing Record 47 of Set 5 | kota kinabalu
# Processing Record 48 of Set 5 | kaitangata
# Processing Record 49 of Set 5 | oranjemund
# Processing Record 50 of Set 5 | vammala
# Processing Record 1 of Set 6 | obreja
# Processing Record 2 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 3 of Set 6 | rajgarh
# Processing Record 4 of Set 6 | geraldton
# Processing Record 5 of Set 6 | beloha
# Processing Record 6 of Set 6 | queanbeyan
# Processing Record 7 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 6 | kargil
# Processing Record 9 of Set 6 | yabelo
# Processing Record 10 of Set 6 | puerto escondido
# Processing Record 11 of Set 6 | usinsk
# Processing Record 12 of Set 6 | kamiiso
# Processing Record 13 of Set 6 | kalomo
# City not found. Skipping...
# Processing Record 14 of Set 6 | chumikan
# Processing Record 15 of Set 6 | thunder bay
# Processing Record 16 of Set 6 | constitucion
# Processing Record 17 of Set 6 | hofn
# Processing Record 18 of Set 6 | djenne
# Processing Record 19 of Set 6 | narsaq
# Processing Record 20 of Set 6 | georgetown
# Processing Record 21 of Set 6 | dukat
# Processing Record 22 of Set 6 | hovd
# Processing Record 23 of Set 6 | dezhou
# Processing Record 24 of Set 6 | ardistan
# City not found. Skipping...
# Processing Record 25 of Set 6 | kemin
# Processing Record 26 of Set 6 | taburi
# City not found. Skipping...
# Processing Record 27 of Set 6 | qui nhon
# Processing Record 28 of Set 6 | basco
# Processing Record 29 of Set 6 | lebu
# Processing Record 30 of Set 6 | saskylakh
# Processing Record 31 of Set 6 | esperance
# Processing Record 32 of Set 6 | kazanskaya
# Processing Record 33 of Set 6 | alofi
# Processing Record 34 of Set 6 | jiangyou
# Processing Record 35 of Set 6 | abu jubayhah
# City not found. Skipping...
# Processing Record 36 of Set 6 | vila franca do campo
# Processing Record 37 of Set 6 | mayumba
# Processing Record 38 of Set 6 | colon
# Processing Record 39 of Set 6 | autazes
# Processing Record 40 of Set 6 | ballina
# Processing Record 41 of Set 6 | batagay-alyta
# Processing Record 42 of Set 6 | alice springs
# Processing Record 43 of Set 6 | toamasina
# Processing Record 44 of Set 6 | dalian
# Processing Record 45 of Set 6 | paris
# Processing Record 46 of Set 6 | teguise
# Processing Record 47 of Set 6 | marsh harbour
# Processing Record 48 of Set 6 | ribeira grande
# Processing Record 49 of Set 6 | loubomo
# Processing Record 50 of Set 6 | yamada
# Processing Record 1 of Set 7 | diapaga
# Processing Record 2 of Set 7 | coos bay
# Processing Record 3 of Set 7 | shadegan
# Processing Record 4 of Set 7 | jha jha
# Processing Record 5 of Set 7 | kushima
# Processing Record 6 of Set 7 | namibe
# Processing Record 7 of Set 7 | wiarton
# Processing Record 8 of Set 7 | san vicente
# Processing Record 9 of Set 7 | roebourne
# Processing Record 10 of Set 7 | nouadhibou
# Processing Record 11 of Set 7 | iquitos
# Processing Record 12 of Set 7 | yulara
# Processing Record 13 of Set 7 | christchurch
# Processing Record 14 of Set 7 | lorengau
# Processing Record 15 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 16 of Set 7 | broken hill
# Processing Record 17 of Set 7 | praya
# Processing Record 18 of Set 7 | cedar city
# Processing Record 19 of Set 7 | kirensk
# Processing Record 20 of Set 7 | brae
# Processing Record 21 of Set 7 | shenjiamen
# Processing Record 22 of Set 7 | ushtobe
# Processing Record 23 of Set 7 | birobidzhan
# Processing Record 24 of Set 7 | ruteng
# Processing Record 25 of Set 7 | torbay
# Processing Record 26 of Set 7 | mao
# Processing Record 27 of Set 7 | baft
# Processing Record 28 of Set 7 | tehachapi
# Processing Record 29 of Set 7 | syracuse
# Processing Record 30 of Set 7 | huaihua
# Processing Record 31 of Set 7 | santa isabel do rio negro
# Processing Record 32 of Set 7 | polis
# Processing Record 33 of Set 7 | balabac
# Processing Record 34 of Set 7 | podor
# Processing Record 35 of Set 7 | tianpeng
# Processing Record 36 of Set 7 | hambantota
# Processing Record 37 of Set 7 | port hedland
# Processing Record 38 of Set 7 | santarem
# Processing Record 39 of Set 7 | laela
# Processing Record 40 of Set 7 | poopo
# Processing Record 41 of Set 7 | coquimbo
# Processing Record 42 of Set 7 | ancud
# Processing Record 43 of Set 7 | sitka
# Processing Record 44 of Set 7 | garowe
# Processing Record 45 of Set 7 | ewa beach
# Processing Record 46 of Set 7 | mizdah
# Processing Record 47 of Set 7 | jumla
# Processing Record 48 of Set 7 | atar
# Processing Record 49 of Set 7 | cartagena
# Processing Record 50 of Set 7 | phetchaburi
# Processing Record 1 of Set 8 | cayenne
# Processing Record 2 of Set 8 | beaune
# Processing Record 3 of Set 8 | poum
# Processing Record 4 of Set 8 | sulina
# Processing Record 5 of Set 8 | fatikchhari
# City not found. Skipping...
# Processing Record 6 of Set 8 | gopichettipalaiyam
# City not found. Skipping...
# Processing Record 7 of Set 8 | raudeberg
# Processing Record 8 of Set 8 | vostok
# Processing Record 9 of Set 8 | areka
# Processing Record 10 of Set 8 | thompson
# Processing Record 11 of Set 8 | bam
# Processing Record 12 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 8 | bosaso
# Processing Record 14 of Set 8 | necochea
# Processing Record 15 of Set 8 | port augusta
# Processing Record 16 of Set 8 | kindu
# Processing Record 17 of Set 8 | poso
# Processing Record 18 of Set 8 | santa maria
# Processing Record 19 of Set 8 | asau
# Processing Record 20 of Set 8 | tautira
# Processing Record 21 of Set 8 | hami
# Processing Record 22 of Set 8 | flinders
# Processing Record 23 of Set 8 | villa de reyes
# Processing Record 24 of Set 8 | bubaque
# Processing Record 25 of Set 8 | singaraja
# Processing Record 26 of Set 8 | pontian kecil
# Processing Record 27 of Set 8 | victor harbor
# Processing Record 28 of Set 8 | somers point
# Processing Record 29 of Set 8 | fez
# Processing Record 30 of Set 8 | bilma
# Processing Record 31 of Set 8 | yanliang
# Processing Record 32 of Set 8 | kirakira
# Processing Record 33 of Set 8 | shingu
# Processing Record 34 of Set 8 | garissa
# Processing Record 35 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 36 of Set 8 | prince rupert
# Processing Record 37 of Set 8 | shangrao
# Processing Record 38 of Set 8 | cleves
# Processing Record 39 of Set 8 | nelson bay
# Processing Record 40 of Set 8 | destin
# Processing Record 41 of Set 8 | havre-saint-pierre
# Processing Record 42 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 43 of Set 8 | sao felix do xingu
# Processing Record 44 of Set 8 | formosa
# Processing Record 45 of Set 8 | tabou
# Processing Record 46 of Set 8 | kalnciems
# Processing Record 47 of Set 8 | leh
# Processing Record 48 of Set 8 | rio gallegos
# Processing Record 49 of Set 8 | sarakhs
# Processing Record 50 of Set 8 | linxia
# Processing Record 1 of Set 9 | bathsheba
# Processing Record 2 of Set 9 | naifaru
# Processing Record 3 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 9 | south sioux city
# Processing Record 5 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 6 of Set 9 | sao filipe
# Processing Record 7 of Set 9 | vyskov
# Processing Record 8 of Set 9 | gap
# Processing Record 9 of Set 9 | baiyin
# Processing Record 10 of Set 9 | waingapu
# Processing Record 11 of Set 9 | shelbyville
# Processing Record 12 of Set 9 | konevo
# Processing Record 13 of Set 9 | nivala
# Processing Record 14 of Set 9 | mount darwin
# Processing Record 15 of Set 9 | pitrufquen
# Processing Record 16 of Set 9 | half moon bay
# Processing Record 17 of Set 9 | benalla
# Processing Record 18 of Set 9 | mayo
# Processing Record 19 of Set 9 | halifax
# Processing Record 20 of Set 9 | claresholm
# Processing Record 21 of Set 9 | turan
# Processing Record 22 of Set 9 | progreso
# Processing Record 23 of Set 9 | qasigiannguit
# Processing Record 24 of Set 9 | campos gerais
# Processing Record 25 of Set 9 | bud
# Processing Record 26 of Set 9 | jalu
# Processing Record 27 of Set 9 | andrews
# Processing Record 28 of Set 9 | tura
# Processing Record 29 of Set 9 | parkes
# Processing Record 30 of Set 9 | bayji
# Processing Record 31 of Set 9 | nauta
# Processing Record 32 of Set 9 | kaputa
# Processing Record 33 of Set 9 | tolaga bay
# Processing Record 34 of Set 9 | duldurga
# Processing Record 35 of Set 9 | abu samrah
# Processing Record 36 of Set 9 | mathathane
# Processing Record 37 of Set 9 | laiagam
# City not found. Skipping...
# Processing Record 38 of Set 9 | santa cruz del sur
# Processing Record 39 of Set 9 | kautokeino
# Processing Record 40 of Set 9 | inhambane
# Processing Record 41 of Set 9 | akureyri
# Processing Record 42 of Set 9 | krasnouralsk
# Processing Record 43 of Set 9 | shelburne
# Processing Record 44 of Set 9 | acapulco
# Processing Record 45 of Set 9 | lasa
# Processing Record 46 of Set 9 | kurilsk
# Processing Record 47 of Set 9 | almaznyy
# Processing Record 48 of Set 9 | itoman
# Processing Record 49 of Set 9 | chegdomyn
# Processing Record 50 of Set 9 | ajaccio
# Processing Record 1 of Set 10 | chatham
# Processing Record 2 of Set 10 | latung
# Processing Record 3 of Set 10 | tabas
# Processing Record 4 of Set 10 | jishou
# Processing Record 5 of Set 10 | neuquen
# Processing Record 6 of Set 10 | palmer
# Processing Record 7 of Set 10 | fuyang
# Processing Record 8 of Set 10 | malanje
# Processing Record 9 of Set 10 | caucasia
# Processing Record 10 of Set 10 | manuk mangkaw
# Processing Record 11 of Set 10 | dingle
# Processing Record 12 of Set 10 | bitung
# Processing Record 13 of Set 10 | stade
# Processing Record 14 of Set 10 | sakakah
# Processing Record 15 of Set 10 | miri
# Processing Record 16 of Set 10 | gamba
# Processing Record 17 of Set 10 | saint george
# Processing Record 18 of Set 10 | layou
# Processing Record 19 of Set 10 | zhigalovo
# Processing Record 20 of Set 10 | cabuyaro
# Processing Record 21 of Set 10 | kaspiysk
# Processing Record 22 of Set 10 | phalaborwa
# Processing Record 23 of Set 10 | santa rosa
# Processing Record 24 of Set 10 | bundaberg
# Processing Record 25 of Set 10 | chara
# Processing Record 26 of Set 10 | asfi
# Processing Record 27 of Set 10 | ouesso
# Processing Record 28 of Set 10 | villa carlos paz
# Processing Record 29 of Set 10 | mackenzie
# Processing Record 30 of Set 10 | venice
# Processing Record 31 of Set 10 | mudyuga
# City not found. Skipping...
# Processing Record 32 of Set 10 | san patricio
# Processing Record 33 of Set 10 | uvalde
# Processing Record 34 of Set 10 | safranbolu
# Processing Record 35 of Set 10 | nanortalik
# Processing Record 36 of Set 10 | lamballe
# Processing Record 37 of Set 10 | portland
# Processing Record 38 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 39 of Set 10 | clovis
# Processing Record 40 of Set 10 | plettenberg bay
# Processing Record 41 of Set 10 | moron
# Processing Record 42 of Set 10 | dod ballapur
# Processing Record 43 of Set 10 | marystown
# Processing Record 44 of Set 10 | saint anthony
# Processing Record 45 of Set 10 | sao sebastiao
# Processing Record 46 of Set 10 | champerico
# Processing Record 47 of Set 10 | asahikawa
# Processing Record 48 of Set 10 | burgersdorp
# Processing Record 49 of Set 10 | rio pardo de minas
# Processing Record 50 of Set 10 | touros
# Processing Record 1 of Set 11 | ostrovnoy
# Processing Record 2 of Set 11 | cockburn town
# Processing Record 3 of Set 11 | kantang
# Processing Record 4 of Set 11 | jiazi
# Processing Record 5 of Set 11 | darhan
# Processing Record 6 of Set 11 | oktyabrskoye
# Processing Record 7 of Set 11 | paso de los toros
# Processing Record 8 of Set 11 | awjilah
# Processing Record 9 of Set 11 | turukhansk
# Processing Record 10 of Set 11 | lopez
# Processing Record 11 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 12 of Set 11 | edinet
# Processing Record 13 of Set 11 | raton
# Processing Record 14 of Set 11 | sept-iles
# Processing Record 15 of Set 11 | senador jose porfirio
# Processing Record 16 of Set 11 | solnechnyy
# Processing Record 17 of Set 11 | el dorado
# Processing Record 18 of Set 11 | praia da vitoria
# Processing Record 19 of Set 11 | ucluelet
# Processing Record 20 of Set 11 | villaviciosa
# Processing Record 21 of Set 11 | feldkirchen an der donau
# Processing Record 22 of Set 11 | betong
# Processing Record 23 of Set 11 | evensk
# Processing Record 24 of Set 11 | vallenar
# Processing Record 25 of Set 11 | cidreira
# Processing Record 26 of Set 11 | ossora
# Processing Record 27 of Set 11 | jaragua
# Processing Record 28 of Set 11 | eureka
# Processing Record 29 of Set 11 | atambua
# Processing Record 30 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 31 of Set 11 | alibag
# Processing Record 32 of Set 11 | maceio
# Processing Record 33 of Set 11 | arshan
# Processing Record 34 of Set 11 | monticello
# Processing Record 35 of Set 11 | dennery
# Processing Record 36 of Set 11 | farafangana
# Processing Record 37 of Set 11 | vao
# Processing Record 38 of Set 11 | myitkyina
# Processing Record 39 of Set 11 | kamakhyanagar
# Processing Record 40 of Set 11 | afrikanda
# Processing Record 41 of Set 11 | paltinis
# Processing Record 42 of Set 11 | coihaique
# Processing Record 43 of Set 11 | ndjole
# Processing Record 44 of Set 11 | aykhal
# Processing Record 45 of Set 11 | chapada dos guimaraes
# Processing Record 46 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 47 of Set 11 | visby
# Processing Record 48 of Set 11 | pimenta bueno
# Processing Record 49 of Set 11 | severo-yeniseyskiy
# Processing Record 50 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 1 of Set 12 | nantucket
# Processing Record 2 of Set 12 | westport
# Processing Record 3 of Set 12 | oranjestad
# Processing Record 4 of Set 12 | irbeyskoye
# Processing Record 5 of Set 12 | whitewater
# Processing Record 6 of Set 12 | bhaderwah
# Processing Record 7 of Set 12 | jiwani
# Processing Record 8 of Set 12 | russell
# Processing Record 9 of Set 12 | dutlwe
# Processing Record 10 of Set 12 | guilin
# Processing Record 11 of Set 12 | shache
# Processing Record 12 of Set 12 | havelock
# Processing Record 13 of Set 12 | takhtamygda
# Processing Record 14 of Set 12 | bat yam
# Processing Record 15 of Set 12 | ketchikan
# Processing Record 16 of Set 12 | oktyabrskiy
# Processing Record 17 of Set 12 | fort nelson
# Processing Record 18 of Set 12 | manitouwadge
# Processing Record 19 of Set 12 | valday
# Processing Record 20 of Set 12 | chabahar
# Processing Record 21 of Set 12 | uyemskiy
# Processing Record 22 of Set 12 | enumclaw
# Processing Record 23 of Set 12 | anito
# Processing Record 24 of Set 12 | a
# City not found. Skipping...
# Processing Record 25 of Set 12 | bahia blanca
# Processing Record 26 of Set 12 | lethem
# Processing Record 27 of Set 12 | paratinga
# Processing Record 28 of Set 12 | galveston
# Processing Record 29 of Set 12 | mozarlandia
# Processing Record 30 of Set 12 | partsa
# Processing Record 31 of Set 12 | rock sound
# Processing Record 32 of Set 12 | eyl
# Processing Record 33 of Set 12 | pierre
# Processing Record 34 of Set 12 | kattivakkam
# Processing Record 35 of Set 12 | nisia floresta
# Processing Record 36 of Set 12 | san juan de abajo
# Processing Record 37 of Set 12 | dauphin
# Processing Record 38 of Set 12 | raga
# Processing Record 39 of Set 12 | ocos
# Processing Record 40 of Set 12 | wanning
# Processing Record 41 of Set 12 | luxor
# Processing Record 42 of Set 12 | loandjili
# Processing Record 43 of Set 12 | turochak
# Processing Record 44 of Set 12 | muriwai beach
# Processing Record 45 of Set 12 | camocim
# Processing Record 46 of Set 12 | xique-xique
# Processing Record 47 of Set 12 | belaya gora
# Processing Record 48 of Set 12 | forest lake
# Processing Record 49 of Set 12 | auki
# Processing Record 50 of Set 12 | harper
# Processing Record 1 of Set 13 | cabatuan
# Processing Record 2 of Set 13 | mackay
# Processing Record 3 of Set 13 | katobu
# Processing Record 4 of Set 13 | pisco
# Processing Record 5 of Set 13 | pudem
# Processing Record 6 of Set 13 | mareeba
# Processing Record 7 of Set 13 | novikovo
# Processing Record 8 of Set 13 | tadine
# Processing Record 9 of Set 13 | kangaatsiaq
# Processing Record 10 of Set 13 | yar-sale
# Processing Record 11 of Set 13 | tandil
# Processing Record 12 of Set 13 | ladario
# Processing Record 13 of Set 13 | doha
# Processing Record 14 of Set 13 | korfovskiy
# Processing Record 15 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 13 | campbellton
# Processing Record 17 of Set 13 | danilov
# Processing Record 18 of Set 13 | faro
# Processing Record 19 of Set 13 | malkangiri
# Processing Record 20 of Set 13 | san juan del sur
# Processing Record 21 of Set 13 | hit
# Processing Record 22 of Set 13 | tsentralnyy
# City not found. Skipping...
# Processing Record 23 of Set 13 | sabha
# Processing Record 24 of Set 13 | beni
# Processing Record 25 of Set 13 | natal
# Processing Record 26 of Set 13 | broome
# Processing Record 27 of Set 13 | urengoy
# Processing Record 28 of Set 13 | sinnamary
# Processing Record 29 of Set 13 | deyang
# Processing Record 30 of Set 13 | kayes
# Processing Record 31 of Set 13 | mildura
# Processing Record 32 of Set 13 | cururupu
# Processing Record 33 of Set 13 | saint-pierre
# Processing Record 34 of Set 13 | laguna
# Processing Record 35 of Set 13 | playas
# Processing Record 36 of Set 13 | lavrentiya
# Processing Record 37 of Set 13 | nortelandia
# Processing Record 38 of Set 13 | maua
# Processing Record 39 of Set 13 | greenville
# Processing Record 40 of Set 13 | mecca
# Processing Record 41 of Set 13 | namatanai
# Processing Record 42 of Set 13 | lodja
# Processing Record 43 of Set 13 | lotoshino
# Processing Record 44 of Set 13 | higuey
# City not found. Skipping...
# Processing Record 45 of Set 13 | palmerston
# Processing Record 46 of Set 13 | nuuk
# Processing Record 47 of Set 13 | griffith
# Processing Record 48 of Set 13 | ribeira brava
# Processing Record 49 of Set 13 | tymovskoye
# Processing Record 50 of Set 13 | gangotri
# City not found. Skipping...
# Processing Record 1 of Set 14 | yumen
# Processing Record 2 of Set 14 | krasnovishersk
# Processing Record 3 of Set 14 | barcelos
# Processing Record 4 of Set 14 | kurchum
# Processing Record 5 of Set 14 | tomigusuku
# Processing Record 6 of Set 14 | vaitape
# Processing Record 7 of Set 14 | yerbogachen
# Processing Record 8 of Set 14 | bandarbeyla
# Processing Record 9 of Set 14 | rafaela
# Processing Record 10 of Set 14 | quatre cocos
# Processing Record 11 of Set 14 | blacksburg
# Processing Record 12 of Set 14 | katha
# City not found. Skipping...
# Processing Record 13 of Set 14 | ponta delgada
# Processing Record 14 of Set 14 | vila velha
# Processing Record 15 of Set 14 | honiara
# Processing Record 16 of Set 14 | silvassa
# Processing Record 17 of Set 14 | scarborough
# Processing Record 18 of Set 14 | abu dhabi
# Processing Record 19 of Set 14 | quelimane
# Processing Record 20 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 21 of Set 14 | herouville-saint-clair
# Processing Record 22 of Set 14 | nouakchott
# Processing Record 23 of Set 14 | zunyi
# Processing Record 24 of Set 14 | qurayyat
# Processing Record 25 of Set 14 | chongwe
# Processing Record 26 of Set 14 | saint-louis
# Processing Record 27 of Set 14 | gemena
# Processing Record 28 of Set 14 | adrar
# Processing Record 29 of Set 14 | collie
# Processing Record 30 of Set 14 | hervey bay
# Processing Record 31 of Set 14 | monchique
# Processing Record 32 of Set 14 | puerto leguizamo
# Processing Record 33 of Set 14 | vung tau
# Processing Record 34 of Set 14 | cumaribo
# City not found. Skipping...
# Processing Record 35 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 36 of Set 14 | najran
# Processing Record 37 of Set 14 | luzilandia
# Processing Record 38 of Set 14 | tomatlan
# Processing Record 39 of Set 14 | tezu
# Processing Record 40 of Set 14 | trat
# Processing Record 41 of Set 14 | urucurituba
# Processing Record 42 of Set 14 | sundsvall
# Processing Record 43 of Set 14 | isangel
# Processing Record 44 of Set 14 | banyo
# Processing Record 45 of Set 14 | jeremoabo
# Processing Record 46 of Set 14 | anloga
# Processing Record 47 of Set 14 | mercedes
# Processing Record 48 of Set 14 | nynashamn
# Processing Record 49 of Set 14 | mpophomeni
# Processing Record 50 of Set 14 | samarai
# Processing Record 1 of Set 15 | arawa
# Processing Record 2 of Set 15 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 15 | port-cartier
# Processing Record 4 of Set 15 | longjiang
# Processing Record 5 of Set 15 | nong khai
# Processing Record 6 of Set 15 | pacasmayo
# Processing Record 7 of Set 15 | sumkino
# Processing Record 8 of Set 15 | takaungu
# Processing Record 9 of Set 15 | tulsipur
# Processing Record 10 of Set 15 | falealupo
# City not found. Skipping...
# Processing Record 11 of Set 15 | marienburg
# Processing Record 12 of Set 15 | uige
# Processing Record 13 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 15 | kruisfontein
# Processing Record 15 of Set 15 | sun valley
# Processing Record 16 of Set 15 | mabaruma
# Processing Record 17 of Set 15 | boguchany
# Processing Record 18 of Set 15 | ullapool
# Processing Record 19 of Set 15 | niigata
# Processing Record 20 of Set 15 | novita
# Processing Record 21 of Set 15 | karratha
# Processing Record 22 of Set 15 | sioux lookout
# Processing Record 23 of Set 15 | at-bashi
# Processing Record 24 of Set 15 | severnyy
# Processing Record 25 of Set 15 | hede
# Processing Record 26 of Set 15 | finschhafen
# Processing Record 27 of Set 15 | kamenka
# Processing Record 28 of Set 15 | duz
# City not found. Skipping...
# Processing Record 29 of Set 15 | birao
# Processing Record 30 of Set 15 | qingdao
# Processing Record 31 of Set 15 | hermiston
# Processing Record 32 of Set 15 | dukuhturi
# Processing Record 33 of Set 15 | rusera
# Processing Record 34 of Set 15 | ewo
# Processing Record 35 of Set 15 | eydhafushi
# Processing Record 36 of Set 15 | caravelas
# Processing Record 37 of Set 15 | andenes
# Processing Record 38 of Set 15 | tiruvottiyur
# City not found. Skipping...
# Processing Record 39 of Set 15 | deniliquin
# Processing Record 40 of Set 15 | ayagoz
# Processing Record 41 of Set 15 | minsk
# Processing Record 42 of Set 15 | meulaboh
# Processing Record 43 of Set 15 | presidencia roque saenz pena
# Processing Record 44 of Set 15 | tubruq
# City not found. Skipping...
# Processing Record 45 of Set 15 | mfou
# Processing Record 46 of Set 15 | santa maria da boa vista
# Processing Record 47 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 48 of Set 15 | sao joao de pirabas
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(cities_data)
# Out:
# 691

# %%
cities_data_df = pd.DataFrame(cities_data)
cities_data_df.head()
# Out:
#               City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0  Krasnozatonskiy      RU  61.6758  50.9794      8.82        92          20
# 1       Carutapera      BR  -1.1950 -46.0200     75.11        93         100
# 2       Valparaiso      CL -33.0393 -71.6273     66.47        72           0
# 3   Ciudad Bolivar      VE   8.1222 -63.5497     74.62        78          66
# 4          Ushuaia      AR -54.8000 -68.3000     44.26        87           0
#
#    Wind Speed Current Description
# 0        6.71          few clouds
# 1        4.00     overcast clouds
# 2        5.75           clear sky
# 3        9.60       broken clouds
# 4        5.75           clear sky

# %%
output_data_file = "weather_database/WeatherPy_database.csv"
cities_data_df.to_csv(output_data_file, index_label="City_ID")
